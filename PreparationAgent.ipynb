# %%
recipes = {
    "poha": [
        "Ingredients: Poha, onion, mustard seeds, curry leaves, turmeric, lemon.",
        "Steps: Rinse poha, sauté onion with spices, add poha, mix, add lemon."
    ],
    "banana smoothie": [
        "Ingredients: Bananas, milk, honey, cinnamon.",
        "Steps: Blend everything and serve chilled."
    ],
    "chicken curry": [
        "Ingredients: Chicken, onion, tomato, ginger garlic paste, curry powder.",
        "Steps: Sauté onion, add tomato & spices, cook chicken for 25 mins."
    ]
}

def recipe_chat():
    print("👩‍🍳 Hi! I'm your Recipe Bot.")
    while True:
        ask = input("Type a recipe name (or 'exit'): ").strip().lower()
        if ask == "exit":
            print("Bye! 👋")
            break
        elif ask in recipes:
            ingredients, steps = recipes[ask]
            print(f"\n📝 {ingredients}")
            print(f"👨‍🍳 {steps}\n")
        else:
            print("❌ Recipe not found. Try another.\n")

recipe_chat()
# Out:
# 👩‍🍳 Hi! I'm your Recipe Bot.
# Type a recipe name (or 'exit'):  chicken curry
# 📝 Ingredients: Chicken, onion, tomato, ginger garlic paste, curry powder.
# 👨‍🍳 Steps: Sauté onion, add tomato & spices, cook chicken for 25 mins.
# Type a recipe name (or 'exit'):  choclate sharjah
# ❌ Recipe not found. Try another.
# Type a recipe name (or 'exit'):  poha
# 📝 Ingredients: Poha, onion, mustard seeds, curry leaves, turmeric, lemon.
# 👨‍🍳 Steps: Rinse poha, sauté onion with spices, add poha, mix, add lemon.
